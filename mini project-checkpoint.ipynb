# %% [markdown]
# # Project title:Analysis of Medical cost of patient

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from string import ascii_letters

# %% [markdown]
# # Getting the data

# %%
data=pd.read_csv("insurance.csv")
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
data.shape
# Out:
# (1338, 7)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# # Visualisation

# %%
plt.figure();

data[['age', 'bmi', 'children', 'charges']].diff().hist(color="darkblue", alpha=0.8, bins=50, figsize=(12, 6));

# %% [markdown]
# Columns children, charges, children, bmi follows fairly normal distribution.

# %%
plt.figure(figsize=(10,6)) 
sns.boxplot(data["charges"],data["sex"])
plt.show()

# %% [markdown]
# Median charges for female is ~ 9413k dollars, Median charges for male is ~ 9369k dollars
#
# The upper fence charges for male is ~ 40k dollars which is much higher than the upper fence charges for female which is ~ 28k dollars

# %%
plt.figure(figsize=(10,6)) 
sns.boxplot(data["charges"],data["smoker"])
plt.show()

# %%
plt.figure(figsize=(10,6)) 
sns.boxplot(data["charges"],data["region"])
plt.show()

# %% [markdown]
# There is no significant visible discrimination in charges based on region.

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of age")
ax = sns.distplot(data["age"], color = 'g')

# %%
sns.catplot(x="smoker", kind="count",hue = 'sex', palette="rainbow", data=data[(data.age == 18)])
plt.title("The number of smokers and non-smokers (18 years old)")
# Out:
# Text(0.5, 1.0, 'The number of smokers and non-smokers (18 years old)')

# %%
plt.figure(figsize=(12,5))
plt.title("Box plot for charges 18 years old smokers")
sns.boxplot(y="smoker", x="charges", data = data[(data.age == 18)] , orient="h", palette = 'pink')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of bmi")
ax = sns.distplot(data["bmi"], color = 'm')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of charges for patients with BMI greater than 30")
ax = sns.distplot(data[(data.bmi >= 30)]['charges'], color = 'b')

# %%
plt.figure(figsize=(12,5))
plt.title("Distribution of charges for patients with BMI less than 30")
ax = sns.distplot(data[(data.bmi < 30)]['charges'], color = 'g')

# %% [markdown]
# Patients with BMI above 30 spend more on treatment!

# %%
plt.figure(figsize=(15,15))
sns.heatmap(data.corr(),annot=True).set_title("Correlation heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation heatmap')

# %% [markdown]
# A strong correlation is observed only with the fact of smoking the patient.

# %%
#Encode the categoricals
from sklearn.preprocessing import LabelEncoder

for c in data.columns:
    if data[c].dtype=='object': 
        lb = LabelEncoder()
        lb.fit(list(data[c].values))
        data[c] = lb.transform(data[c].values)

# %%
data.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
#spliting and scaling
#Feature scaling


X = data.drop(['charges'], axis = 1)
y = data['charges']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.75, random_state = 0)

from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
X_test
# Out:
# array([[ 0.84747516,  0.9589266 , -0.06741834, -0.09193944, -0.51957865,
#          1.25516541],
#        [ 0.48355551, -1.04283268, -0.20021435, -0.09193944, -0.51957865,
#          0.35938497],
#        [ 0.55633944,  0.9589266 ,  1.59093188,  0.73800038,  1.92463642,
#         -0.53639548],
#        ...,
#        [ 1.28417875,  0.9589266 , -0.8713942 , -0.92187927, -0.51957865,
#         -1.43217592],
#        [ 1.28417875, -1.04283268,  0.19257386,  0.73800038, -0.51957865,
#         -1.43217592],
#        [ 0.77469123, -1.04283268, -1.60337222, -0.92187927, -0.51957865,
#          1.25516541]])

# %%
#model training and testing
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
ln = LinearRegression()

knn = KNeighborsRegressor(n_neighbors=10)

dt = DecisionTreeRegressor(max_depth = 3)

regressors = [('Linear Regression', ln), ('K Nearest Neighbours', knn),
               ('Decision Tree', dt)]

# %%
from sklearn.metrics import r2_score

for regressor_name, regressor in regressors:
 
    # Fit regressor to the training set
    regressor.fit(X_train, y_train)    
   
    # Predict 
    y_pred = regressor.predict(X_test)
    accuracy = round(r2_score(y_test,y_pred),1)*100
    print('{:s} : {:.0f} %'.format(regressor_name, accuracy))
# Out:
# Linear Regression : 80 %
# K Nearest Neighbours : 80 %
# Decision Tree : 80 %

# %% [markdown]
#  the accuracy of algorithms we analyse that all algorithm has the same accuracy. So, KNN ,Linear Regression,Decision Tree  algorithms  used for creating the model.
