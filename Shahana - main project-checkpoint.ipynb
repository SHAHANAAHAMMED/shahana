# %% [markdown]
# # Project Title: Bank Churn  analysis

# %% [markdown]
# # Indroduction

# %% [markdown]
# Customers  leaving credit cards services would lead bank to loss, so we analyze the data of customers and identify the customers who will leave their credit card services and reason for same .

# %% [markdown]
# # Feature Description

# %% [markdown]
# CLIENTNUM: Client number. Unique identifier for the customer holding the account
# Attrition_Flag: Internal event (customer activity) variable - if the account is closed then "Attrited Customer" else "Existing Customer"
# Customer_Age: Age in Years
# Gender: Gender of the account holder
# Dependent_count: Number of dependents
# Education_Level: Educational Qualification of the account holder - Graduate, High School, Unknown, Uneducated, College(refers to a college student), Post-Graduate, Doctorate.
# Marital_Status: Marital Status of the account holder
# Income_Category: Annual Income Category of the account holder
# Card_Category: Type of Card
# Months_on_book: Period of relationship with the bank
# Total_Relationship_Count: Total no. of products held by the customer
# Months_Inactive_12_mon: No. of months inactive in the last 12 months
# Contacts_Count_12_mon: No. of Contacts between the customer and bank in the last 12 months
# Credit_Limit: Credit Limit on the Credit Card
# Total_Revolving_Bal: The balance that carries over from one month to the next is the revolving balance
# Avg_Open_To_Buy: Open to Buy refers to the amount left on the credit card to use (Average of last 12 months)
# Total_Trans_Amt: Total Transaction Amount (Last 12 months)
# Total_Trans_Ct: Total Transaction Count (Last 12 months)
# Total_Ct_Chng_Q4_Q1: Ratio of the total transaction count in 4th quarter and the total transaction count in 1st quarter
# Total_Amt_Chng_Q4_Q1: Ratio of the total transaction amount in 4th quarter and the total transaction amount in 1st quarter
# Avg_Utilization_Ratio: Represents how much of the available credit the customer spent

# %% [markdown]
# # import libraries

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
from collections import Counter

# %% [markdown]
# # Getting the dataset

# %%
df = pd.read_csv("D:\edub\PROJECT\BankChurners.csv")
df
# Out:
#        CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      768805383  Existing Customer            45      M                3
# 1      818770008  Existing Customer            49      F                5
# 2      713982108  Existing Customer            51      M                3
# 3      769911858  Existing Customer            40      F                4
# 4      709106358  Existing Customer            40      M                3
# ...          ...                ...           ...    ...              ...
# 10122  772366833  Existing Customer            50      M                2
# 10123  710638233  Attrited Customer            41      M                2
# 10124  716506083  Attrited Customer            44      F                1
# 10125  717406983  Attrited Customer            30      M                2
# 10126  714337233  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# ...

# %%
df.drop(columns=df.columns[-2:],inplace=True)

# %% [markdown]
# # Data analysis

# %%
##viewing data
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %%
#Checking shape
df.shape
# Out:
# (10127, 21)

# %%
#Checking for null values
df.isnull().sum()
# Out:
# CLIENTNUM                   0
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['CLIENTNUM', 'Attrition_Flag', 'Customer_Age', 'Gender',
#        'Dependent_count', 'Education_Level', 'Marital_Status',
#        'Income_Category', 'Card_Category', 'Months_on_book',
#        'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio'],
#       dtype='object')

# %%
#Viewing descriptive statistics
df.describe()
# Out:
#           CLIENTNUM  Customer_Age  Dependent_count  Months_on_book  \
# count  1.012700e+04  10127.000000     10127.000000    10127.000000
# mean   7.391776e+08     46.325960         2.346203       35.928409
# std    3.690378e+07      8.016814         1.298908        7.986416
# min    7.080821e+08     26.000000         0.000000       13.000000
# 25%    7.130368e+08     41.000000         1.000000       31.000000
# 50%    7.179264e+08     46.000000         2.000000       36.000000
# 75%    7.731435e+08     52.000000         3.000000       40.000000
# max    8.283431e+08     73.000000         5.000000       56.000000
#
#        Total_Relationship_Count  Months_Inactive_12_mon  \
# count              10127.000000            10127.000000
# mean                   3.812580                2.341167
# std                    1.554408                1.010622
# min                    1.000000                0.000000
# 25%                    3.000000                2.000000
# ...

# %%
# if the account is closed then 1(Attrited Customer) else 0(Existing Customer)
df['churn'] = (df.Attrition_Flag == 'Attrited Customer')*1

df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Contacts_Count_12_mon  Credit_Limit  \
# 0              39  ...                      3       12691.0
# ...

# %%
#Checking info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10127 entries, 0 to 10126
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   CLIENTNUM                 10127 non-null  int64
#  1   Attrition_Flag            10127 non-null  object
#  2   Customer_Age              10127 non-null  int64
#  3   Gender                    10127 non-null  object
#  4   Dependent_count           10127 non-null  int64
#  5   Education_Level           10127 non-null  object
#  6   Marital_Status            10127 non-null  object
#  7   Income_Category           10127 non-null  object
#  8   Card_Category             10127 non-null  object
#  9   Months_on_book            10127 non-null  int64
#  10  Total_Relationship_Count  10127 non-null  int64
#  11  Months_Inactive_12_mon    10127 non-null  int64
#  12  Contacts_Count_12_mon     10127 non-null  int64
# ...

# %%
X = df.drop('Attrition_Flag', axis=1)
y = df['Attrition_Flag']

# %%
df1=df.drop("CLIENTNUM",axis=1)
df1
# Out:
#           Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0      Existing Customer            45      M                3
# 1      Existing Customer            49      F                5
# 2      Existing Customer            51      M                3
# 3      Existing Customer            40      F                4
# 4      Existing Customer            40      M                3
# ...                  ...           ...    ...              ...
# 10122  Existing Customer            50      M                2
# 10123  Attrited Customer            41      M                2
# 10124  Attrited Customer            44      F                1
# 10125  Attrited Customer            30      M                2
# 10126  Attrited Customer            43      F                2
#
#       Education_Level Marital_Status Income_Category Card_Category  \
# 0         High School        Married     $60K - $80K          Blue
# 1            Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# # Visualisation

# %%
#Q1 : What is the count of Existing customer and Attrited customer?
plt.figure(figsize = (10,6))
sns.countplot(x = df['Attrition_Flag'], )
plt.show()

# %% [markdown]
# In the above graph show that most customers are existing

# %%
#Q2: What is the card category of customers based on gender?
plt.figure(figsize = (15, 8))
sns.countplot(x = df['Card_Category'], hue = df['Gender'])
plt.show()

# %% [markdown]
# The majority of customers use blue cards and female customers are used it, followed by Silver , Gold  and Platinum .

# %%
#Q3: What is the education level of customers?
plt.figure(figsize = (10,6))
sns.countplot(x= df['Education_Level'], edgecolor = 'black', saturation = 0.55)
plt.show()

# %% [markdown]
# The graph tells us the education level of the customers. Most of the people using the bank have Graduate, with only around 1,500 not being educated.

# %%
#Q4: What is the relationship between  Total Transaction Amount and cound in customers?
fig,axes=plt.subplots(1,2,sharex=True,figsize=(14,6))
sns.scatterplot(ax=axes[0],x=df["Total_Trans_Amt"],y=df["Total_Trans_Ct"])
sns.regplot(ax=axes[1],x=df["Total_Trans_Amt"],y=df["Total_Trans_Ct"])
plt.show()

# %%
#Q5: What is the distribution of Total_Amt_Chng_Q4_Q1
plt.figure(figsize = (10, 8))
sns.distplot(df['Total_Amt_Chng_Q4_Q1'],kde=False)

# %%
plt.figure(figsize = (15, 8))
sns.distplot(df['Total_Trans_Ct'])

# %%
#Q6: Which age category is more attrited?
plt.figure(figsize = (18,10))
plt.title("Age with Churned or not", fontsize = 30)
sns.countplot(data = df, x = df["Customer_Age"], hue = "Attrition_Flag")

# %% [markdown]
# Customer in age range 41-55 attrited most

# %%
#Q7: What is percentage of churned customers?
fig, ax = plt.subplots(figsize=(7, 7))
count = Counter(y)
ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title('Percentage of existing and attrited/churned customers')
plt.show()

# %% [markdown]
#  pie chart which shows that roughly 84% of customers in our data are staying with the same firm, while 16% left.

# %%
#Q8: What is the marital status of customers?

fig, ax = plt.subplots(figsize=(8, 7))
count = Counter(X['Marital_Status'])
labels = []

for i in count:
    labels.append(i + ' (' + str(count[i]/len(X['Marital_Status'])*100)[:5] + '%)')
    
plt.bar(labels, count.values(), color='green')
plt.title('Marital status for customers')
plt.ylabel('Number of customers')
plt.xlabel('Marital status')
plt.show()

# %% [markdown]
# The marital status of the customers in our bank shows us that around half are married, roughly 40% are single, and 7% are unknown and 7% divorced.

# %%
#Q9: What is the no.of relationship for customers?
fig, ax = plt.subplots(figsize=(7, 6))
count = Counter(X['Total_Relationship_Count'])
count = pd.Series(count).sort_values(ascending=False)
labels = []

for i in count.keys():
    labels.append(str(i) + ' (' + str(count[i]/len(X['Total_Relationship_Count'])*100)[:5] + '%)')
    
plt.bar(labels, count, color='maroon')
plt.title('Number of relationships for customers')
plt.ylabel('Customers')
plt.xlabel('Number of relationships')
plt.show()

# %% [markdown]
# The most common number of relationships people have had is three (22%), followed by four, five and six, which have roughly 18% each.

# %%
#Q10: What is the income of most of the customers?
fig, ax = plt.subplots(figsize=(8, 6))
count = Counter(X['Income_Category'])

ax.pie(count.values(), labels=count.keys(), autopct=lambda p:f'{p:.2f}%')
ax.set_title('Income per customer')
plt.show()

# %% [markdown]
# More than a third of the people make less than  40𝐾,and the next most commen category is 40-60K, which is almost half as frequent. After that is  80−120𝐾(15%), 60-80K (14%), Unknown (11%) and then $120K+ (7%).

# %%
#Q11: What is the high period of relationship with bank of customer?
def plt_feature_by_churn(feature_name):
    fig = plt.figure(figsize=(16,10))
    sns.countplot(feature_name,data=df,hue='churn')
    if df[feature_name].dtype != 'O':
        print('correlation between ', feature_name, ' and churn:', df[[feature_name, 'churn']].corr().iloc[0,1])

plt_feature_by_churn('Months_on_book')
# Out:
# correlation between  Months_on_book  and churn: 0.013686851177909888

# %% [markdown]
# 36 is the high period that relationship of customers with bank.And that customers still exist in bank.

# %%
#Q12: What is the relation between incom and credit limit?
plt.figure(figsize=(10,5)) 
sns.set_palette(sns.color_palette("Set2", 8))

sns.barplot(y='Credit_Limit',x='Income_Category',hue='Attrition_Flag',data=df)
sns.despine(top=True,right=True,left=True) # to remove side line from graph
plt.legend(bbox_to_anchor=(1.00, 1))
plt.title('Relation between Income and credit')
# Out:
# Text(0.5, 1.0, 'Relation between Income and credit')

# %% [markdown]
# credit limit and incom is almost same for exixting and attrited customers.And who have 120K+ salary their creadit limit is high followed by others.

# %%
#Q13: Which card is high amount transacted?
plt.figure(figsize=(10,5))
sns.barplot(y='Total_Trans_Amt',x='Card_Category',hue='Attrition_Flag',data=df) 
sns.despine(top=True,right=True,left=True) # to remove side line from graph
plt.legend(bbox_to_anchor=(1.00, 1))
plt.title('Total Transaction Amount  vs Card')
# Out:
# Text(0.5, 1.0, 'Total Transaction Amount  vs Card')

# %% [markdown]
# platinum card holders are more amount transacted.And low transaction done by blue card holders.

# %%
#Q14: Compare customers inactive in last 12 month and contact in last month
plt.figure(figsize=(15,7))
sns.lineplot(df.Contacts_Count_12_mon,df.Months_Inactive_12_mon,df.Attrition_Flag)

# %%
#Q15: What is the relation of Ratio of the total transaction count in 4 &1 quarter and Ratio of the total transaction amount in 4&1 quarter?
plt.figure(figsize=(15,7))
sns.scatterplot(x='Total_Ct_Chng_Q4_Q1', y='Total_Amt_Chng_Q4_Q1',hue='Attrition_Flag',data=df)

# %%
#Q16: which card category is balance that carries over from one month to the next ?
fig,a=plt.subplots(1,1,figsize=(10,6))
df["Card_Category"].value_counts().plot(kind="bar",color=["darkblue"])
plt.xlabel("Card_Category")
plt.ylabel("Total_Revolving_Bal")
plt.show()

df.groupby("Card_Category")["Card_Category"].count().sort_values(ascending=False)
# Out:
# Card_Category
# Blue        9436
# Silver       555
# Gold         116
# Platinum      20
# Name: Card_Category, dtype: int64

# %%
#Q17: how much of the available credit the customer spent based of existing/churn customers?
plt.figure(figsize=(10,6)) 
sns.boxplot(df["Attrition_Flag"],df["Avg_Utilization_Ratio"])
plt.show()

df.groupby("Attrition_Flag")["Avg_Utilization_Ratio"].mean().sort_values(ascending=False)
# Out:
# Attrition_Flag
# Existing Customer    0.296412
# Attrited Customer    0.162475
# Name: Avg_Utilization_Ratio, dtype: float64

# %%
#Q18:What is the correlation between dependent count and churn?
plt_feature_by_churn('Dependent_count')
# Out:
# correlation between  Dependent_count  and churn: 0.01899059631119562

# %%
#Q19:What is the ratio of gender they churn or to stay

plt.figure(figsize=(10,5))
sns.set_palette(sns.color_palette("tab10", 8))
sns.countplot(hue=df["Attrition_Flag"],x=df["Gender"])
plt.show()

# %% [markdown]
# It seems like that female customer and male customer both have a similar ratio to churn or to stay.

# %%
#Q20: 
plt.figure(figsize=(10,10))
sns.barplot(df['Attrition_Flag'],df['Total_Trans_Ct'],hue=df['Education_Level'])
plt.show()

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df1.corr(),annot=True).set_title("Correlation heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation heatmap')

# %% [markdown]
# The features in our dataset have some correlation, for example, Months_on_book and Customer_age, Avg_Utilization_Ratio and Total_Revolving_Bal.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Most people are blue credit card holders,also it was the owners of blue cards who mostly left the bank.
#
# The data set is unbalanced.16% of customers left the bank and 84% customers stay.
#
# Most customers have an income of $ 40000 per year
#
# Most of the people using the bank have Graduate, with only around 1,500 not being educated.
#
# platinum card holders are more amount transacted.And low transaction done by blue card holders.
#
# Total transaction amount and Total number of transactions = 0.81, high positive correlation.
#
# We also have a dependency: most of the people who left the bank had from 30 to 80 transactions in their account and from 2500 to 10000 conventional units
#
# Also an interesting fact: most of the bank's customers are women, and most of the lost customers are also women
#
# Using correlation analysis,The features in our dataset have correlation
